# %%
# %sql
create catalog if not exists retail_data

# %%
# %sql
use catalog retail_data

# %%
# %sql
create schema if not exists retail_data.bronze

# %%
# %sql
create schema if not exists retail_data.silver

# %%
# %sql
create schema if not exists retail_data.gold
